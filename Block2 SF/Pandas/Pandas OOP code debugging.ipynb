# %%
"""ОБЪЕКТЫ
Некоторые данные и действия над ними могут объединяться вместе в единый объект. В Python всё по сути является
объектом. Объект числа хранит своё значение — данные, мы можем вызвать его методы, совершать действия."""

number = 2.5   
# Вызовем метод is_integer. Он скажет нам, является ли number целым числом  
print(number.is_integer())  
# => False  
  
# Давайте попробуем представить number как обыкновенную дробь  
print(number.as_integer_ratio())  
# => (5, 2)  
# Действительно 2.5 = 5/2 

#Посмотрим на список: он хранит данные своих элементов, мы можем совершать над ними действия встроенными методами.
people = ["Vasiliy", "Stanislav", "Alexandra", "Vasiliy"]  
  
# Посчитаем число Василиев с помощью метода count  
print(people.count("Vasiliy"))  
# => 2  
  
# Теперь отсортируем   
people.sort()  
print(people)  
# => ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy'] 

"""КЛАССЫ
У всех встроенных объектов есть свой класс. В примере для числа 2.5 мы видим класс действительных чисел (float),
для списка — класс списка (list). Класс — это некая заготовка или чертёж, которая описывает общую структуру, свойства
и действия для объектов."""
number = 2.5  
print(number.__class__)  
# => <class 'float'>  
  
people = ["Vasiliy", "Stanislav", "Alexandra", "Vasiliy"]  
print(people.__class__)  
# => <class 'list'> 

#Определим пустой класс: он не делает ничего, но позволит нам посмотреть на синтаксис.

# Используем ключевое слово class, за которым идёт название класса, в примере это SalesReport  
class SalesReport():  
    pass  
  
# Сравните это с определением пустой функции  
# Команда pass не делает ничего; на её месте могли быть другие инструкции  
# Мы используем её только потому, что синтаксически python требует, чтобы там было хоть что-то  
def build_report():  
    pass  
  
  
# И давайте определим ещё один класс  
# Для имён классов традиционно используются имена в формате CamelCase, где начала слов отмечаются большими буквами  
# Это позволяет легко отличать их от функций, которые пишутся в формате snake_case  
class SkillfactoryStudent():  
    pass

#Мы написали свой первый класс — давайте создадим по нему объект. Вызываем класс и получаем новый объект аналогично
#тому, как вызывается функция. Получаем результат.
class SalesReport():  
    pass  
  
# создаём объект по классу  
report = SalesReport()  
  
# мы можем создавать множество объектов по одному классу  
report_2 = SalesReport()  
  
# Это будут разные объекты.   
print(report == report_2)  
# => False  
#Созданный таким образом объект часто называют экземпляром класса (instance). Такое название вы будете часто
#встречать в статьях и книгах.

"""АТРИБУТЫ И МЕТОДЫ
Мы создали объект по пустому классу. Давайте добавим ему данные. Сделаем класс для отчётов по продажам SalesReport.
Пусть у нас в компании есть менеджеры по продажам, которые заключают сделки, и мы хотим посчитать для них метрики
общего объёма продаж."""

# По-прежнему пока создаём пустой класс  
class SalesReport():  
    pass  
  
# Создаём первый отчёт по продажам   
report = SalesReport()  
  
# Мы добавим новый атрибут объекту.  
# Для этого через точку напишем имя атрибута и дальше как с обычной переменной  
report.amount = 10  
  
# То же самое делаем для второго отчёта.  
report_2 = SalesReport()  
report_2.amount = 20  
  
# Создадим вспомогательную функцию, она будет печатать общую сумму из отчёта  
def print_report(report):  
    print("Total amount:", report.amount)  
      
print_report(report) # => Total amount: 10  
print_report(report_2) # => Total amount: 20 

#Для разных отчётов вывелись разные значения, хотя объекты создавались из одного класса. Функция print_report делает
#операцию над отчётом. Так как классы увязывают данные и действия над ними, положим print_report внутрь класса.
class SalesReport():  
    # Наш новый метод внутри класса.  
    # Мы определяем его похожим образом с обычными функциями,  
    #   но только помещаем внутрь класса и первым аргументом передаём self  
    def print_report(self):  
        print("Total amount:", self.amount)  
          
          
# Дальше мы применяем report так же, как и в примере выше   
report = SalesReport()  
report.amount = 10  
  
report_2 = SalesReport()  
report_2.amount = 20  
  
# Используем наши новые методы  
report.print_report() # => Total amount: 10  
report_2.print_report() # => Total amount: 20 

"""В методе мы первым аргументом получаем self — в нашем случае это отчёт, что позволяет использовать атрибуты
объекта внутри метода, как мы сделали с amount. Self передаётся автоматически. При вызове метода мы не передавали
никакие аргументы."""

#Давайте для примера определим ещё пару методов:
class SalesReport():  
    # Позволим добавлять много разных сделок   
    def add_deal(self, amount):   
        # На первой сделке создадим список для хранения всех сделок   
        if not hasattr(self, 'deals'):  
            self.deals = []  
        # Добавим текущую сделку  
        self.deals.append(amount)  
          
    # Посчитаем сумму всех сделок      
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
          
# Используем наши новые возможности  
# Добавим две сделки и распечатаем отчёт  
report = SalesReport()  
report.add_deal(10_000)  
report.add_deal(30_000)  
report.print_report() # => Total sales: 40000
"""Атрибут deals, определённый в одном методе, становится доступен сразу во всех методах класса. Через self
становятся доступны и остальные методы, например print_report использует метод total_amount. Это позволяет компактно
упаковывать логику внутри класса: внешнее использование становится гораздо лаконичнее."""
# Out:
# False
# (5, 2)
# 2
# ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy']
# <class 'float'>
# <class 'list'>
# False

# %%
"""Допишите определение класса DepartmentReport,который выводит отчёт по отделам компании.У него должны быть определены:

атрибут revenues — список, где мы храним значения выручки отделов;
метод add_revenue, который добавляет выручку одного отдела;
метод average_revenue, который возвращает среднюю выручку по всем отделам.
В случае правильного описания класса код, приведённый ниже, должен выдать следующий результат:

report = DepartmentReport()
report.add_revenue(1_000_000)
report.add_revenue(400_000)
print(report.revenues)
# [1000000, 400000]
print(report.average_revenue())
# 700000.0"""

class DepartmentReport():
    def add_revenue(self,value):
        if not hasattr(self,'revenue'):
            self.revenue=[]
        self.revenue.append(value)
        
    def average_revenue(self):
        return sum(self.revenue)/len(self.revenue)  
#    def print_report(self):
#        print("Average revenue: ",self.average_revenue())
report = DepartmentReport()
report.add_revenue(1000000)
report.add_revenue(400000)
print(report.revenue)
# [1000000, 400000]
print(report.average_revenue())
# 700000.0
# Out:
# [1000000, 400000]
# 700000.0

# %%
"""МЕТОД _INIT_
Если мы вызовем total_amount до add_deal, то список сделок ещё не будет создан, и мы получим ошибку. Также проверка
на наличие списка в методе add_deal не кажется оптимальным решением, потому что создать список нужно один раз, а
проверять его наличие мы вынуждены на каждой сделке.
class SalesReport():  
    def add_deal(self, amount):   
        if not hasattr(self, 'deals'):  
            self.deals = []  
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
          
report = SalesReport()  
report.total_amount()  
# => AttributeError"""

#Обе проблемы решились бы, если задавать атрибутам исходное значение. Для этого у классов есть метод инициализации
#__init__. Если мы определим метод с таким именем, код в нём вызовется при создании объекта.
class SalesReport():
    def __init__(self):
        self.deals=[]
        
    def add_deal(self,amount):
        self.deals.append(amount)
            
    def total_amount(self):
        return sum(self.deals)
    
    def print_report(self):
        print ("Total amount = ",self.total_amount())
        
report=SalesReport()
report.total_amount()
report.add_deal(10)
report.add_deal(20)
report.print_report()

"""__init__ — это технический метод, поэтому его имя начинается и заканчивается двумя подчёркиваниями. Он получает
первым аргументом сам объект, в нём могут выполняться любые операции. Оставшиеся аргументы он получает из вызова
при создании: если мы напишем report = SalesReport("Info", 20), то вторым и третьим аргументом в __init__ передадутся
"Info" и 20."""
class SalesReport():
    # Будем принимать в __init__ ещё и имя менеджера 
    def __init__(self,manager_name):
        self.deals=[]
        self.manager_name=manager_name
        
    def add_deal(self,amount):
        self.deals.append(amount)
        
    def total_amount(self):
        return sum(self.deals)
    
    def print_report(self):
        #И добавлять это имя в отчёт
        print("Manager name:",self.manager_name)
        print("Total sales:",self.total_amount())
        
report=SalesReport("Vasul Maron")
report.add_deal(5)
report.add_deal(25)
report.print_report()

#Допустим, теперь мы хотим получать средний размер сделки и список клиентов, из которого исключены повторения (в
#случае, если компания заключала несколько сделок с одним и тем же клиентом)
class SalesReport():
    def __init__(self,employee_name):
        self.deals=[]
        self.employee_name=employee_name
        
    def add_deal(self,company,amount):
        self.deals.append({'company':company,'amount':amount})
        
    def total_amount(self):
        return sum([i['amount']for i in self.deals])
    
    def average_deal(self):
        return self.total_amount()/len(self.deals)
    
    def all_companies(self):
        return list(set([i['company'] for i in self.deals]))
    
    def print_report(self):  
        print("Employee: ", self.employee_name)  
        print("Total sales:", self.total_amount())  
        print("Average sales:", self.average_deal())  
        print("Companies:", self.all_companies())  

report=SalesReport("Pavlo Terenchuk")
report.add_deal("PepsiCo",4000)
report.add_deal("SkyEng",7500)
report.add_deal("PepsiCo",4500)
report.print_report()
# Out:
# Total amount =  30
# Manager name: Vasul Maron
# Total sales: 30
# Employee:  Pavlo Terenchuk
# Total sales: 16000
# Average sales: 5333.333333333333
# Companies: ['PepsiCo', 'SkyEng']

# %%
"""Практические примеры
ОТСЛЕЖИВАНИЕ СОСТОЯНИЯ
Одно из классических предписаний для классов — у каждого из множества объектов есть некоторые меняющиеся состояния. 
Вернёмся к примеру: есть база клиентов с основной информацией; в реальном времени нам приходит информация о покупках.
Запустим промокампанию, чтобы поощрить старых клиентов, которые сделали у нас много заказов, и выдать им скидку:"""
class Client():
    #Basical data
    def __init__(self,email,order_num,registration_year):
        self.email=email
        self.order_num=order_num
        self.registration_year=registration_year
        self.discount=0
        
    #Order processing
    def make_order(self,price):
        self.update_discount()
        self.order_num+=1
        #Здесь было бы оформление заказа, но мы просто выведем его цену
        discounted_price=price*(1-self.discount)
        print(f"Order price for {self.email} is {discounted_price}")
        
    def update_discount(self):
        if self.registration_year<2018 and self.order_num>=5:
            self.discount=0.1        
# Application
          
# Let's make a similar base
client_db=[
    Client("max@gmail.com", 2, 2019),  
    Client("lova@yandex.ru", 10, 2015),  
    Client("german@sberbank.ru", 4, 2017)
]

#Generate an order
client_db[0].make_order(100)  
# => Order price for max@gmail.com is 100  
  
client_db[1].make_order(200)  
# => Order price for lova@yandex.ru is 180.0  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 500  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 450.0
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0

# %%
class Client():
    #Basical data
    def __init__(self,email,order_num,registration_year):
        self.email=email
        self.order_num=order_num
        self.registration_year=registration_year
        self.discount=0
 
    def update_discount(self):
        if self.registration_year<2018 and self.order_num>=5:
            self.discount=0.1    
        
    #Order processing
    def make_order(self,price):
        self.update_discount()
        self.order_num+=1
        #Здесь было бы оформление заказа, но мы просто выведем его цену
        discounted_price=price*(1-self.discount)
        print(f"Order price for {self.email} is {discounted_price}")
        
        
# Application
          
# Let's make a similar base
client_db=[
    Client("max@gmail.com", 2, 2019),  
    Client("lova@yandex.ru", 10, 2015),  
    Client("german@sberbank.ru", 4, 2017)
]

#Generate an order
client_db[0].make_order(100)  
# => Order price for max@gmail.com is 100  
  
client_db[1].make_order(200)  
# => Order price for lova@yandex.ru is 180.0  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 500  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 450.0 

class User():
    def __init__(self,email,password,balance):
        self.email=email
        self.password=password
        self.balance=balance
        
    def login(self,email,password):
        if self.email==email and self.password==password:
            return True
        return False
            
    def update_balance(self,amount):
        self.balance+=amount
                           
user = User("gosha@roskino.org", "qwerty", 20_000)
print(user.login("gosha@roskino.org", "qwerty123"))
# False
print(user.login("gosha@roskino.org", "qwerty"))
# True
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# 19700

"""class User():
    def __init__(self, email, password, balance):
        self.email=email
        self.password=password
        self.balance=balance
        update_balance=0

    def login(self, email, password):
        if self.email==email and self.password==password:
            answer=True
        else:
            answer=False
        return answer

    def update_balance(self, amount):
        self.balance+=amount
        return self.balance
"""
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0
# False
# True
# 19700
# 'class User():\n    def __init__(self, email, password, balance):\n        self.email=email\n        self.password=password\n        self.balance=balance\n        update_balance=0\n\n    def login(self, email, password):\n        if self.email==email and self.password==password:\n            answer=True\n        else:\n            answer=False\n        return answer\n\n    def update_balance(self, amount):\n        self.balance+=amount\n        return self.balance\n'

# %%
"""КОМБИНАЦИЯ ОПЕРАЦИЙ
У нас есть численные данные из разных источников. Если они в виде строк, то нужно привести их к числам, а пропуски
— заполнить значениями. Сделаем доступ к медиане, среднему значению и стандартному отклонению:"""
import statistics
  
class DataFrame():  
    def __init__(self, column, fill_value=0):  
        # Инициализируем атрибуты  
        self.column = column 
        self.fill_value = fill_value  
        # Заполним пропуски  
        self.fill_missed()  
        # Конвертируем все элементы в числа  
        self.to_float()  
          
    def fill_missed(self): #does it means with self - we mentioned any attribute in init function?
        for i,value in enumerate(self.column):  #why we`ve used "enumerate", cause "list indices must be integers 
            #or slices, not NoneType"
            if value is None or value == '':  
                self.column[i] = self.fill_value  
                  
    def to_float(self):  
        self.column = [float(value) for value in self.column]  
      
    def median(self):  
        return statistics.median(self.column)  #why apply median function to statistics?
      
    def mean(self):  
        return statistics.mean(self.column)  
      
    def deviation(self):  
        return statistics.stdev(self.column)  
      
# Воспользуемся классом  
df = DataFrame(["1", 17, 4, None, 8])  
  
print(df.column)  
# => [1.0, 17.0, 4.0, 0.0, 8.0]  
print(df.deviation())  
# => 6.89  
print(df.median())  
# => 4.0 
#Мы получили очень лаконичный интерфейс для использования класса. В __init__ мы использовали значение по умолчанию
#для fill_value, а методы позволяют нам определять необязательные параметры.
"""class IntDataFrame():
    def __init__(self, column):
        self.column=column
        self.to_int()

    def to_int(self):
        self.column=[int(value) for value in self.column]

    def count(self):
        j=0
        for i, value in enumerate(self.column):
            if value>0:
                j+=1
        return j

    def unique(self):
        uniq=[]
        for i, value in enumerate(self.column):
            if value in uniq:
                continue
            else:
                uniq.append(value)
        return len(uniq)"""
        
class IntDataFrame():
    def __init__(self,list_df):
        self.list_df=list_df
        self.transition_positive()
        
    def transition_positive(self):
        self.list_df=[int(i)for i in self.list_df] #Why without return?
        
    def count_non_zero(self):
        print (len(self.list_df) - self.list_df.count(0))
            
    def unique_count(self):
        list_unique=[]
        for i,value in enumerate(self.list_df):#without enumerate can`t work?..in transition func(above) didn`t use it
            if value in list_unique:
                continue
            else:
                list_unique.append(value)
        return len(list_unique)
            

df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])

df.count_non_zero()
# 5
df.unique_count()
# 4
df.list_df
# Out:
# [1.0, 17.0, 4.0, 0.0, 8.0]
# 6.892024376045111
# 4.0
# 5
# [4, 4, 3, 0, 2, 0, 4]

# %%
"""КЛАСС-ОБЁРТКА 
Классы можно использовать тогда, когда у вас есть процесс, который требует сложной конфигурации, повторяющейся из
раза в раз. Можно написать класс-обёртку, который сведёт этот процесс к одному-двум методам.
Представим, вы делаете обработку данных и в конце каждого дня сохраняете результат в архив. Вы хотите, чтобы данные
каждого дня лежали в отдельном файле для этого дня, при этом можно было бы получить данные за произвольный день. 
Перед запуском кода создайте папку с названием archive там же, где находится ноутбук:"""

import pickle  
from datetime import datetime  
from os import path  
  
class Dumper():  
    def __init__(self, archive_dir="archive/"):  
        self.archive_dir = archive_dir  
          
    def dump(self, data):  
        # Библиотека pickle позволяет доставать и класть объекты в файл  
        with open(self.get_file_name(), 'wb') as file:  #wb -режим відкриття та запису
            pickle.dump(data, file)  
              
    def load_for_day(self, day):  
        file_name = path.join(self.archive_dir, day + ".pkl")   
        with open(file_name, 'rb') as file:  
            sets = pickle.load(file)  
        return sets  
          
    # возвращает корректное имя для файла   
    def get_file_name(self):   
        today = datetime.now().strftime("%y-%m-%d")   
        return path.join(self.archive_dir, today + ".pkl")  
      
      
# Пример использования  
  
data = {  
    'perfomance': [10, 20, 10],  
    'clients': {"Romashka": 10, "Vector": 34}  
}  
  
  
dumper = Dumper()  
  
# Сохраним данные  
dumper.dump(data)  
  
# Восстановим для сегодняшней даты  
file_name = datetime.now().strftime("%y-%m-%d")
restored_data = dumper.load_for_day(file_name)
print(restored_data)  
# => {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}
# Out:
# {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}

# %%
"""Напишите класс сборщика технических сообщений OwnLogger.
У него должен быть
атрибут logs, содержащий {"info": None, "warning": None, "error": None, "all": None}.
метод log(message, level), который записывает сообщения. Здесь сообщение message может быть любым, а level
— один из "info", "warning", "error".
метод show_last(level), где level может быть "info", "warning", "error", "all".
Для "all" он просто возвращает последнее добавленное сообщение, а для остальных — последнее поступившее сообщение
соответствующего уровня. При этом по умолчанию значение именно "all".
Если подходящего сообщения нет, возвращает None."""
class OwnLogger():
    def __init__(self):
        self.logs = {"info": None, "warning": None, "error": None, "all": None}
    def log(self, message, level):
        self.logs[level] = message
        self.logs['all'] = message
    def show_last(self, level='all'):
        return self.logs[level]
        
logger3=OwnLogger()#без инит біли бі разніе ссілки на один обєкт
logger = OwnLogger()
logger.log("System started", "info")
logger.show_last("error")
# None
# Некоторые интерпретаторы Python могут не выводить None, тогда в этой проверке у вас будет пустая строка
logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")

logger.show_last()
# Connection lost
logger.show_last("info")
# System started
# Out:
# 'Connection lost'

# %%
"""Классы, как и библиотечные функции, можно импортировать в другие программы. Для этого нужно положить класс в
отдельный файл в корне проекта и использовать ключевое слово import. 
Например, если мы положим Dumper в файл dumper.py в корне проекта, то его можно импортировать командой:
from dumper import Dumper  
Пишем from <имя файла без .py> import <имя класса>. Имя файла должно начинаться с буквы и не совпадать с именами
библиотечных модулей. Если файлов с классами много, их можно складывать в папки, предварительно положив туда пустой
файл __init__.py — это требование Python."""
from client_class import Client
from DataFrame_class import DataFrame

client_db=[
    Client("max@gmail.com", 2, 2019),  
    Client("lova@yandex.ru", 10, 2015),  
    Client("german@sberbank.ru", 4, 2017)
]

#Generate an order
client_db[0].make_order(100)  
# => Order price for max@gmail.com is 100  
client_db[1].make_order(200)  
# => Order price for lova@yandex.ru is 180.0   
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 500   
client_db[2].make_order(500) 
#Order price for german@sberbank.ru is 450.0

df = DataFrame(["1", 17, 4, None, 8])  
  
print(df.column)  
# => [1.0, 17.0, 4.0, 0.0, 8.0]  
print(df.deviation())  
# => 6.89  
print(df.median())  

#У вас есть класс DataBase, где метод __init__ принимает один аргумент. Какой код создаст объект этого класса и
#положит его в переменную db?
#db = DataBase()

#В папке animals в файле dog.py лежит класс Dog. Напишите команду, которая импортирует этот класс.
#from animals.dog import Dog

#Определите класс Dog, у которого есть методы bark и give_paw. При этом, пусть методы принимают список из любого
# количества аргументов. bark возвращает строку "Bark!"  give_paw возвращает строку "Paw".
"""class Dog():
    def bark(*args):
        return 'Bark!'

    def give_paw(*args):
        return 'Paw'
    
doggy = Dog([4,3,2,1])
doggy.bark()
TypeError:Dog() takes no arguments"""

class Dog():
    def __init__(self,*args):
        self.args=args
        
    def bark(self,*args):
        print ("Bark!")
        
    def give_paw (self,*args):
        print ("Paw")
        
doggy=Dog()
doggy.bark([1,5,4])
doggy.give_paw([1,4])
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0
# [1.0, 17.0, 4.0, 0.0, 8.0]
# 6.892024376045111
# 4.0

# %%
helpers
-- __init__.py
-- DataFrame_class.py
-- client_class.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 helpers
#       2 -- __init__.py
#       3 -- DataFrame_class.py
#
# NameError: name 'helpers' is not defined

# %%
"""Чтобы поработать с путями, есть модуль os. Функция os.chdir() позволяет нам изменить директорию, которую мы
в данный момент используем. Если вам нужно знать, какой путь вы в данный момент используете, для этого нужно
вызвать os.getcwd()."""
import os
os.getcwd()
# получить текущий путь
start_path = os.getcwd()
print(start_path) # /home/nbuser/library
#Далее попробуем подняться на директорию выше:
os.chdir("..") # подняться на один уровень выше
os.getcwd() # '/home/nbuser''
#Теперь вернемся в ту директорию, из которой стартовали. Изначально мы сохраняли её в переменной start_path.
os.chdir(start_path)
os.getcwd() # '/home/nbuser/library'
#С помощью функции os.listdir() можно получить весь список файлов, находящихся в директории. Если не указать никаких
#аргументов, то будет взята текущая директория.
# список файлов и директорий в папке
import os
print(os.listdir()) # ['SnapchatLoader', 'FBLoader', 'tmp.py', '.gitignore', 'venv', '.git']
if 'tmp.py' not in os.listdir():
    print("Файл отсутствует в данной директории")
"""Для того чтобы склеивать пути с учётом особенностей ОС, следует использовать функцию os.path.join(). Это связано
с тем, что в разных операционных системах могут быть разные разделители каталогов, например в ОС Windows этим
разделителем является «\», а в Linux — «/», как мы и говорили в начале юнита. Поэтому, чтобы поиск файла проходил
гладко в обеих системах (ведь ваш скрипт могут запускать на любой системе в связи с кросс-платформенностью Python),
лучше всё-таки использовать os.path.join()"""
# соединяет пути с учётом особенностей операционной системы
print(start_path)
print(os.path.join(start_path, 'test'))
# /home/nbuser/library
# /home/nbuser/library/test
#Сделайте функцию,которая принимает от пользователя путь и выводит всю информацию о содержимом этой папки.Для реализации
#используйте функцию встроенного модуля os.walk(). Если путь не указан, то сравнение начинается с текущеq директории.
import os

def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd() # current working directory

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc()
# Out:
# c:\Homework Skillfactory\Block2 SF\Pandas
# ['archive', 'client_class.py', 'DataFrame_class.py', 'data_test', 'helpers', 'Pandas cleaning data.ipynb', 'Pandas Data Joining.ipynb', 'Pandas Data manipulation.ipynb', 'Pandas Data manipulation2.ipynb', 'Pandas Data Viualisation.ipynb', 'Pandas DataFrame Practise.ipynb', 'Pandas DataFrame.ipynb', 'Pandas OOP code debugging.ipynb', 'Pandas series.ipynb', 'Pandas Visualisation practise bank.ipynb', 'Types_of_visualization.ipynb', 'Visualization_Pandas.ipynb', 'Viualisation.ipynb', '__init__.py', '__pycache__']
# Файл отсутствует в данной директории

# %%
import os
def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd() # current working directory
    #'c:\\Homework Skillfactory\\Block2 SF\\Pandas'

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc('c:\\Homework Skillfactory\\') #why can`t apply \Block2 SF\Pandas and give only current directory
walk_desc()
# Out:
# Текущая директория c:\Homework Skillfactory\
# ---
# Список папок ['.git', '.vscode', 'Block2 SF', 'Block3 SF', 'data', 'graphics.py-5.0.1.post1', '__pycache__']
# ---
# Список файлов ['C practise.cpp', 'game.ipynb', 'game.py', 'game_v2.py', 'Hyrianov MFTI lection5.ipynb', 'Hyrianov MFTI lection6.ipynb', 'Hyrianov MFTI lection7.ipynb', 'practise CE OMET.ipynb', 'practise with tutor.ipynb', 'requirements.txt', 'test_2.py', 'test_HW.ipynb', 'The route programe.ipynb']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\C practise.cpp
# Файл  c:\Homework Skillfactory\game.ipynb
# Файл  c:\Homework Skillfactory\game.py
# Файл  c:\Homework Skillfactory\game_v2.py
# Файл  c:\Homework Skillfactory\Hyrianov MFTI lection5.ipynb
# Файл  c:\Homework Skillfactory\Hyrianov MFTI lection6.ipynb
# Файл  c:\Homework Skillfactory\Hyrianov MFTI lection7.ipynb
# Файл  c:\Homework Skillfactory\practise CE OMET.ipynb
# Файл  c:\Homework Skillfactory\practise with tutor.ipynb
# Файл  c:\Homework Skillfactory\requirements.txt
# Файл  c:\Homework Skillfactory\test_2.py
# Файл  c:\Homework Skillfactory\test_HW.ipynb
# Файл  c:\Homework Skillfactory\The route programe.ipynb
# Папка  c:\Homework Skillfactory\.git
# Папка  c:\Homework Skillfactory\.vscode
# Папка  c:\Homework Skillfactory\Block2 SF
# Папка  c:\Homework Skillfactory\Block3 SF
# Папка  c:\Homework Skillfactory\data
# Папка  c:\Homework Skillfactory\graphics.py-5.0.1.post1
# Папка  c:\Homework Skillfactory\__pycache__
# ===
# Текущая директория c:\Homework Skillfactory\.git
# ---
# Список папок ['hooks', 'info', 'logs', 'objects', 'refs']
# ---
# Список файлов ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\.git\COMMIT_EDITMSG
# Файл  c:\Homework Skillfactory\.git\config
# Файл  c:\Homework Skillfactory\.git\description
# Файл  c:\Homework Skillfactory\.git\FETCH_HEAD
# Файл  c:\Homework Skillfactory\.git\HEAD
# Файл  c:\Homework Skillfactory\.git\index
# Файл  c:\Homework Skillfactory\.git\ORIG_HEAD
# Папка  c:\Homework Skillfactory\.git\hooks
# Папка  c:\Homework Skillfactory\.git\info
# Папка  c:\Homework Skillfactory\.git\logs
# Папка  c:\Homework Skillfactory\.git\objects
# Папка  c:\Homework Skillfactory\.git\refs
# ===
# Текущая директория c:\Homework Skillfactory\.git\hooks
# ---
# Папок нет
# ---
# Список файлов ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ---
# Файл  c:\Homework Skillfactory\.git\hooks\applypatch-msg.sample
# Файл  c:\Homework Skillfactory\.git\hooks\commit-msg.sample
# Файл  c:\Homework Skillfactory\.git\hooks\fsmonitor-watchman.sample
# Файл  c:\Homework Skillfactory\.git\hooks\post-update.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-applypatch.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-commit.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-merge-commit.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-push.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-rebase.sample
# Файл  c:\Homework Skillfactory\.git\hooks\pre-receive.sample
# Файл  c:\Homework Skillfactory\.git\hooks\prepare-commit-msg.sample
# Файл  c:\Homework Skillfactory\.git\hooks\push-to-checkout.sample
# Файл  c:\Homework Skillfactory\.git\hooks\update.sample
# ===
# Текущая директория c:\Homework Skillfactory\.git\info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  c:\Homework Skillfactory\.git\info\exclude
# ===
# Текущая директория c:\Homework Skillfactory\.git\logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\.git\logs\HEAD
# Папка  c:\Homework Skillfactory\.git\logs\refs
# ===
# Текущая директория c:\Homework Skillfactory\.git\logs\refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  c:\Homework Skillfactory\.git\logs\refs\heads
# Папка  c:\Homework Skillfactory\.git\logs\refs\remotes
# ===
# Текущая директория c:\Homework Skillfactory\.git\logs\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  c:\Homework Skillfactory\.git\logs\refs\heads\master
# ===
# Текущая директория c:\Homework Skillfactory\.git\logs\refs\remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  c:\Homework Skillfactory\.git\logs\refs\remotes\origin
# ===
# Текущая директория c:\Homework Skillfactory\.git\logs\refs\remotes\origin
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  c:\Homework Skillfactory\.git\logs\refs\remotes\origin\master
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects
# ---
# Список папок ['00', '01', '02', '03', '04', '05', '0a', '0d', '11', '12', '14', '15', '1a', '1d', '20', '21', '23', '24', '27', '29', '2a', '2b', '2c', '2d', '2e', '30', '32', '33', '34', '35', '36', '38', '39', '3a', '3d', '3f', '40', '45', '46', '47', '4d', '4e', '4f', '51', '52', '53', '55', '57', '59', '5a', '5b', '5c', '60', '64', '66', '67', '6b', '6f', '70', '71', '75', '77', '78', '7a', '7d', '83', '84', '85', '86', '87', '88', '8a', '8b', '90', '93', '95', '97', '98', '9c', '9d', 'a1', 'a4', 'a5', 'a6', 'a9', 'ab', 'ac', 'b0', 'b1', 'b2', 'b3', 'b7', 'b9', 'ba', 'bb', 'bd', 'c4', 'c5', 'c7', 'c8', 'cd', 'ce', 'd2', 'd4', 'd6', 'd7', 'db', 'dc', 'de', 'e0', 'e2', 'e3', 'e4', 'e6', 'e7', 'eb', 'ec', 'ee', 'f0', 'f1', 'f5', 'f7', 'f8', 'fa', 'fd', 'ff', 'info', 'pack']
# ---
# Файлов нет
# ---
# Папка  c:\Homework Skillfactory\.git\objects\00
# Папка  c:\Homework Skillfactory\.git\objects\01
# Папка  c:\Homework Skillfactory\.git\objects\02
# Папка  c:\Homework Skillfactory\.git\objects\03
# Папка  c:\Homework Skillfactory\.git\objects\04
# Папка  c:\Homework Skillfactory\.git\objects\05
# Папка  c:\Homework Skillfactory\.git\objects\0a
# Папка  c:\Homework Skillfactory\.git\objects\0d
# Папка  c:\Homework Skillfactory\.git\objects\11
# Папка  c:\Homework Skillfactory\.git\objects\12
# Папка  c:\Homework Skillfactory\.git\objects\14
# Папка  c:\Homework Skillfactory\.git\objects\15
# Папка  c:\Homework Skillfactory\.git\objects\1a
# Папка  c:\Homework Skillfactory\.git\objects\1d
# Папка  c:\Homework Skillfactory\.git\objects\20
# Папка  c:\Homework Skillfactory\.git\objects\21
# Папка  c:\Homework Skillfactory\.git\objects\23
# Папка  c:\Homework Skillfactory\.git\objects\24
# Папка  c:\Homework Skillfactory\.git\objects\27
# Папка  c:\Homework Skillfactory\.git\objects\29
# Папка  c:\Homework Skillfactory\.git\objects\2a
# Папка  c:\Homework Skillfactory\.git\objects\2b
# Папка  c:\Homework Skillfactory\.git\objects\2c
# Папка  c:\Homework Skillfactory\.git\objects\2d
# Папка  c:\Homework Skillfactory\.git\objects\2e
# Папка  c:\Homework Skillfactory\.git\objects\30
# Папка  c:\Homework Skillfactory\.git\objects\32
# Папка  c:\Homework Skillfactory\.git\objects\33
# Папка  c:\Homework Skillfactory\.git\objects\34
# Папка  c:\Homework Skillfactory\.git\objects\35
# Папка  c:\Homework Skillfactory\.git\objects\36
# Папка  c:\Homework Skillfactory\.git\objects\38
# Папка  c:\Homework Skillfactory\.git\objects\39
# Папка  c:\Homework Skillfactory\.git\objects\3a
# Папка  c:\Homework Skillfactory\.git\objects\3d
# Папка  c:\Homework Skillfactory\.git\objects\3f
# Папка  c:\Homework Skillfactory\.git\objects\40
# Папка  c:\Homework Skillfactory\.git\objects\45
# Папка  c:\Homework Skillfactory\.git\objects\46
# Папка  c:\Homework Skillfactory\.git\objects\47
# Папка  c:\Homework Skillfactory\.git\objects\4d
# Папка  c:\Homework Skillfactory\.git\objects\4e
# Папка  c:\Homework Skillfactory\.git\objects\4f
# Папка  c:\Homework Skillfactory\.git\objects\51
# Папка  c:\Homework Skillfactory\.git\objects\52
# Папка  c:\Homework Skillfactory\.git\objects\53
# Папка  c:\Homework Skillfactory\.git\objects\55
# Папка  c:\Homework Skillfactory\.git\objects\57
# Папка  c:\Homework Skillfactory\.git\objects\59
# Папка  c:\Homework Skillfactory\.git\objects\5a
# Папка  c:\Homework Skillfactory\.git\objects\5b
# Папка  c:\Homework Skillfactory\.git\objects\5c
# Папка  c:\Homework Skillfactory\.git\objects\60
# Папка  c:\Homework Skillfactory\.git\objects\64
# Папка  c:\Homework Skillfactory\.git\objects\66
# Папка  c:\Homework Skillfactory\.git\objects\67
# Папка  c:\Homework Skillfactory\.git\objects\6b
# Папка  c:\Homework Skillfactory\.git\objects\6f
# Папка  c:\Homework Skillfactory\.git\objects\70
# Папка  c:\Homework Skillfactory\.git\objects\71
# Папка  c:\Homework Skillfactory\.git\objects\75
# Папка  c:\Homework Skillfactory\.git\objects\77
# Папка  c:\Homework Skillfactory\.git\objects\78
# Папка  c:\Homework Skillfactory\.git\objects\7a
# Папка  c:\Homework Skillfactory\.git\objects\7d
# Папка  c:\Homework Skillfactory\.git\objects\83
# Папка  c:\Homework Skillfactory\.git\objects\84
# Папка  c:\Homework Skillfactory\.git\objects\85
# Папка  c:\Homework Skillfactory\.git\objects\86
# Папка  c:\Homework Skillfactory\.git\objects\87
# Папка  c:\Homework Skillfactory\.git\objects\88
# Папка  c:\Homework Skillfactory\.git\objects\8a
# Папка  c:\Homework Skillfactory\.git\objects\8b
# Папка  c:\Homework Skillfactory\.git\objects\90
# Папка  c:\Homework Skillfactory\.git\objects\93
# Папка  c:\Homework Skillfactory\.git\objects\95
# Папка  c:\Homework Skillfactory\.git\objects\97
# Папка  c:\Homework Skillfactory\.git\objects\98
# Папка  c:\Homework Skillfactory\.git\objects\9c
# Папка  c:\Homework Skillfactory\.git\objects\9d
# Папка  c:\Homework Skillfactory\.git\objects\a1
# Папка  c:\Homework Skillfactory\.git\objects\a4
# Папка  c:\Homework Skillfactory\.git\objects\a5
# Папка  c:\Homework Skillfactory\.git\objects\a6
# Папка  c:\Homework Skillfactory\.git\objects\a9
# Папка  c:\Homework Skillfactory\.git\objects\ab
# Папка  c:\Homework Skillfactory\.git\objects\ac
# Папка  c:\Homework Skillfactory\.git\objects\b0
# Папка  c:\Homework Skillfactory\.git\objects\b1
# Папка  c:\Homework Skillfactory\.git\objects\b2
# Папка  c:\Homework Skillfactory\.git\objects\b3
# Папка  c:\Homework Skillfactory\.git\objects\b7
# Папка  c:\Homework Skillfactory\.git\objects\b9
# Папка  c:\Homework Skillfactory\.git\objects\ba
# Папка  c:\Homework Skillfactory\.git\objects\bb
# Папка  c:\Homework Skillfactory\.git\objects\bd
# Папка  c:\Homework Skillfactory\.git\objects\c4
# Папка  c:\Homework Skillfactory\.git\objects\c5
# Папка  c:\Homework Skillfactory\.git\objects\c7
# Папка  c:\Homework Skillfactory\.git\objects\c8
# Папка  c:\Homework Skillfactory\.git\objects\cd
# Папка  c:\Homework Skillfactory\.git\objects\ce
# Папка  c:\Homework Skillfactory\.git\objects\d2
# Папка  c:\Homework Skillfactory\.git\objects\d4
# Папка  c:\Homework Skillfactory\.git\objects\d6
# Папка  c:\Homework Skillfactory\.git\objects\d7
# Папка  c:\Homework Skillfactory\.git\objects\db
# Папка  c:\Homework Skillfactory\.git\objects\dc
# Папка  c:\Homework Skillfactory\.git\objects\de
# Папка  c:\Homework Skillfactory\.git\objects\e0
# Папка  c:\Homework Skillfactory\.git\objects\e2
# Папка  c:\Homework Skillfactory\.git\objects\e3
# Папка  c:\Homework Skillfactory\.git\objects\e4
# Папка  c:\Homework Skillfactory\.git\objects\e6
# Папка  c:\Homework Skillfactory\.git\objects\e7
# Папка  c:\Homework Skillfactory\.git\objects\eb
# Папка  c:\Homework Skillfactory\.git\objects\ec
# Папка  c:\Homework Skillfactory\.git\objects\ee
# Папка  c:\Homework Skillfactory\.git\objects\f0
# Папка  c:\Homework Skillfactory\.git\objects\f1
# Папка  c:\Homework Skillfactory\.git\objects\f5
# Папка  c:\Homework Skillfactory\.git\objects\f7
# Папка  c:\Homework Skillfactory\.git\objects\f8
# Папка  c:\Homework Skillfactory\.git\objects\fa
# Папка  c:\Homework Skillfactory\.git\objects\fd
# Папка  c:\Homework Skillfactory\.git\objects\ff
# Папка  c:\Homework Skillfactory\.git\objects\info
# Папка  c:\Homework Skillfactory\.git\objects\pack
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\00
# ---
# Папок нет
# ---
# Список файлов ['133b99d79364d6586c3288350b4b2205872dec']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\00\133b99d79364d6586c3288350b4b2205872dec
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\01
# ---
# Папок нет
# ---
# Список файлов ['a4c90ca587afacbf2236ae73e1cdb168e89d74']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\01\a4c90ca587afacbf2236ae73e1cdb168e89d74
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\02
# ---
# Папок нет
# ---
# Список файлов ['ca4d91199011c6550f4aafefbb12841aa915c6', 'f38bc7282225debac5d20dda638a35df43d8a6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\02\ca4d91199011c6550f4aafefbb12841aa915c6
# Файл  c:\Homework Skillfactory\.git\objects\02\f38bc7282225debac5d20dda638a35df43d8a6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\03
# ---
# Папок нет
# ---
# Список файлов ['a79dec1061e318b2ab0fb7260bc02a01a95626']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\03\a79dec1061e318b2ab0fb7260bc02a01a95626
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\04
# ---
# Папок нет
# ---
# Список файлов ['85417689121b1e185c876a07afc1af7e34bc14', 'b061bc04c423c0a19ebfb8a5b892ba09f34969']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\04\85417689121b1e185c876a07afc1af7e34bc14
# Файл  c:\Homework Skillfactory\.git\objects\04\b061bc04c423c0a19ebfb8a5b892ba09f34969
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\05
# ---
# Папок нет
# ---
# Список файлов ['83e7ff3337512b0152c7436ec5401c30c1509b', 'a23dfb5ec2358f66fe90a05728ba3133b762ef']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\05\83e7ff3337512b0152c7436ec5401c30c1509b
# Файл  c:\Homework Skillfactory\.git\objects\05\a23dfb5ec2358f66fe90a05728ba3133b762ef
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\0a
# ---
# Папок нет
# ---
# Список файлов ['f30692e75d773296f6e89e023e034406422317']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\0a\f30692e75d773296f6e89e023e034406422317
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\0d
# ---
# Папок нет
# ---
# Список файлов ['3e4e01a384cd0135b827199fac5fc04734cfea', '490481eee1ed7529c31090589b6560b49943a3', 'f72413015814ddd86b52faf6e3c0d7c25329ba']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\0d\3e4e01a384cd0135b827199fac5fc04734cfea
# Файл  c:\Homework Skillfactory\.git\objects\0d\490481eee1ed7529c31090589b6560b49943a3
# Файл  c:\Homework Skillfactory\.git\objects\0d\f72413015814ddd86b52faf6e3c0d7c25329ba
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\11
# ---
# Папок нет
# ---
# Список файлов ['4b91348314db31ae1751904565a6d39f62a58f', '88c0cdee8c48b3aed96aba24fabdde5aa4d497']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\11\4b91348314db31ae1751904565a6d39f62a58f
# Файл  c:\Homework Skillfactory\.git\objects\11\88c0cdee8c48b3aed96aba24fabdde5aa4d497
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\12
# ---
# Папок нет
# ---
# Список файлов ['975dd761c8f1ed6d7d69037a6c937348caf199']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\12\975dd761c8f1ed6d7d69037a6c937348caf199
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\14
# ---
# Папок нет
# ---
# Список файлов ['f3e2d90833456f57994d6190551dd89f7fa390']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\14\f3e2d90833456f57994d6190551dd89f7fa390
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\15
# ---
# Папок нет
# ---
# Список файлов ['d815a5639bf7408f2c1ee6411b5074bdd5b2e7']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\15\d815a5639bf7408f2c1ee6411b5074bdd5b2e7
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\1a
# ---
# Папок нет
# ---
# Список файлов ['1c50442a233552c59a68447cfd9b4fcf53cc0c', '823f403af3304ffe0093d416602362a1a8c23b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\1a\1c50442a233552c59a68447cfd9b4fcf53cc0c
# Файл  c:\Homework Skillfactory\.git\objects\1a\823f403af3304ffe0093d416602362a1a8c23b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\1d
# ---
# Папок нет
# ---
# Список файлов ['80e3d864def77bff12a50c5e59f1fb963adca1', 'cfcdcfab28f3a28460f902bbeff2f9ca2bda0c']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\1d\80e3d864def77bff12a50c5e59f1fb963adca1
# Файл  c:\Homework Skillfactory\.git\objects\1d\cfcdcfab28f3a28460f902bbeff2f9ca2bda0c
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\20
# ---
# Папок нет
# ---
# Список файлов ['01a9e671026991a7d4aa0fb4255e1d27d22ac6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\20\01a9e671026991a7d4aa0fb4255e1d27d22ac6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\21
# ---
# Папок нет
# ---
# Список файлов ['834682fb0dc258d5bb2aac012757c39f0a12dd']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\21\834682fb0dc258d5bb2aac012757c39f0a12dd
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\23
# ---
# Папок нет
# ---
# Список файлов ['3391ce18b68190e25dc94d6a9e0eef5d5704aa']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\23\3391ce18b68190e25dc94d6a9e0eef5d5704aa
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\24
# ---
# Папок нет
# ---
# Список файлов ['1927a595a187aa7bebea003b9b77cc77ee972f', 'c6ff4776d3c0722553bfae73233ce90231ae2f']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\24\1927a595a187aa7bebea003b9b77cc77ee972f
# Файл  c:\Homework Skillfactory\.git\objects\24\c6ff4776d3c0722553bfae73233ce90231ae2f
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\27
# ---
# Папок нет
# ---
# Список файлов ['c998098977bd868055ef9f059d241cb6f48f89']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\27\c998098977bd868055ef9f059d241cb6f48f89
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\29
# ---
# Папок нет
# ---
# Список файлов ['3bfe6ba1e296fb204a0e129a636990836bf40a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\29\3bfe6ba1e296fb204a0e129a636990836bf40a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\2a
# ---
# Папок нет
# ---
# Список файлов ['048271604a3f7c47709a5ebd44f30dfbb92ec1']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\2a\048271604a3f7c47709a5ebd44f30dfbb92ec1
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\2b
# ---
# Папок нет
# ---
# Список файлов ['f71489e1a4ab94d3972834ef89095799e031de']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\2b\f71489e1a4ab94d3972834ef89095799e031de
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\2c
# ---
# Папок нет
# ---
# Список файлов ['1b2e74fe24d0fc851aa9745702fcd7777f690a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\2c\1b2e74fe24d0fc851aa9745702fcd7777f690a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\2d
# ---
# Папок нет
# ---
# Список файлов ['e393a06b198678f21451bc8bf962831566a0e8']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\2d\e393a06b198678f21451bc8bf962831566a0e8
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\2e
# ---
# Папок нет
# ---
# Список файлов ['bc0396b311fbe252371bc40255143cca37809f']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\2e\bc0396b311fbe252371bc40255143cca37809f
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\30
# ---
# Папок нет
# ---
# Список файлов ['6f58eb37e8f9ce600a78f311665fb4d079a8c3', 'e2440065269cdffc3f18930d54da0057ae6f5e']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\30\6f58eb37e8f9ce600a78f311665fb4d079a8c3
# Файл  c:\Homework Skillfactory\.git\objects\30\e2440065269cdffc3f18930d54da0057ae6f5e
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\32
# ---
# Папок нет
# ---
# Список файлов ['86a6b4654289a461ba43c3c3812b274b1d52d0']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\32\86a6b4654289a461ba43c3c3812b274b1d52d0
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\33
# ---
# Папок нет
# ---
# Список файлов ['781b1faa6a2185941b1d5707234e92b80557ad']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\33\781b1faa6a2185941b1d5707234e92b80557ad
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\34
# ---
# Папок нет
# ---
# Список файлов ['a1ec1d3c6707578adb0d6a45c745399a8bc17e']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\34\a1ec1d3c6707578adb0d6a45c745399a8bc17e
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\35
# ---
# Папок нет
# ---
# Список файлов ['c9efec8b132741eed2f58206daa92da000092e']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\35\c9efec8b132741eed2f58206daa92da000092e
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\36
# ---
# Папок нет
# ---
# Список файлов ['5618e422181497667c3dd163cd850cfa96ee26', 'c5ce050bbd0d683556c544a4d4faa7bdc1855b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\36\5618e422181497667c3dd163cd850cfa96ee26
# Файл  c:\Homework Skillfactory\.git\objects\36\c5ce050bbd0d683556c544a4d4faa7bdc1855b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\38
# ---
# Папок нет
# ---
# Список файлов ['15368883c3ef386c3e4964d934cba5cb09c8af', '9d3cf62889483745c26702147dbacfc831f022', 'a8ef4f77b029d5bc8bfb504591460d1cce9cf8']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\38\15368883c3ef386c3e4964d934cba5cb09c8af
# Файл  c:\Homework Skillfactory\.git\objects\38\9d3cf62889483745c26702147dbacfc831f022
# Файл  c:\Homework Skillfactory\.git\objects\38\a8ef4f77b029d5bc8bfb504591460d1cce9cf8
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\39
# ---
# Папок нет
# ---
# Список файлов ['c321e94f16c52987e1a02d0f5f7b917c7a7f59', 'e2987bef7fb9025ae3b013ead8f28beac6327e']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\39\c321e94f16c52987e1a02d0f5f7b917c7a7f59
# Файл  c:\Homework Skillfactory\.git\objects\39\e2987bef7fb9025ae3b013ead8f28beac6327e
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\3a
# ---
# Папок нет
# ---
# Список файлов ['00fb9f70e2d8908b1e7fb02fa15b60af690264']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\3a\00fb9f70e2d8908b1e7fb02fa15b60af690264
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\3d
# ---
# Папок нет
# ---
# Список файлов ['96c6011600d9598198def054f68cfaa5b277a4']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\3d\96c6011600d9598198def054f68cfaa5b277a4
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\3f
# ---
# Папок нет
# ---
# Список файлов ['09e472413921227934b65ea41d83edfdb3834e']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\3f\09e472413921227934b65ea41d83edfdb3834e
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\40
# ---
# Папок нет
# ---
# Список файлов ['048a80d46ae320084b510f73499c411cc03967', '4b0eeb2ef934643aa96be49c5976af7d10cca3', 'c700a89d2abeb3a4f461facce9d43ff972caed']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\40\048a80d46ae320084b510f73499c411cc03967
# Файл  c:\Homework Skillfactory\.git\objects\40\4b0eeb2ef934643aa96be49c5976af7d10cca3
# Файл  c:\Homework Skillfactory\.git\objects\40\c700a89d2abeb3a4f461facce9d43ff972caed
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\45
# ---
# Папок нет
# ---
# Список файлов ['92c72aa421e877fe55ed2ccb092baeb8c1420d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\45\92c72aa421e877fe55ed2ccb092baeb8c1420d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\46
# ---
# Папок нет
# ---
# Список файлов ['b2cf1009c1da09260dec5eaac44cd46136e65f']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\46\b2cf1009c1da09260dec5eaac44cd46136e65f
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\47
# ---
# Папок нет
# ---
# Список файлов ['57c1d5d2f9cc79bc37c96f02c84416572fc48b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\47\57c1d5d2f9cc79bc37c96f02c84416572fc48b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\4d
# ---
# Папок нет
# ---
# Список файлов ['5373ffc708f86ecc14ab753abd82ee67c8b025']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\4d\5373ffc708f86ecc14ab753abd82ee67c8b025
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\4e
# ---
# Папок нет
# ---
# Список файлов ['5afbcabc5b6a8507eebb1880b9a933291aa2f8']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\4e\5afbcabc5b6a8507eebb1880b9a933291aa2f8
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\4f
# ---
# Папок нет
# ---
# Список файлов ['e706363c9a4502bc267410779be4b1ca0bfcf1']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\4f\e706363c9a4502bc267410779be4b1ca0bfcf1
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\51
# ---
# Папок нет
# ---
# Список файлов ['40d51a469d7451914d66c78f412b308a216e99', '875775441bfe8e94da05a66c46f54b4ae7ca12']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\51\40d51a469d7451914d66c78f412b308a216e99
# Файл  c:\Homework Skillfactory\.git\objects\51\875775441bfe8e94da05a66c46f54b4ae7ca12
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\52
# ---
# Папок нет
# ---
# Список файлов ['15f4cdd391dac5779f1df4d4d01e792c8bab14', '8c5a26e3c578a1713a9891b2344a923efa3d6d', 'bfa9d6df672ee2d72ce0806eb97738371d24b2']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\52\15f4cdd391dac5779f1df4d4d01e792c8bab14
# Файл  c:\Homework Skillfactory\.git\objects\52\8c5a26e3c578a1713a9891b2344a923efa3d6d
# Файл  c:\Homework Skillfactory\.git\objects\52\bfa9d6df672ee2d72ce0806eb97738371d24b2
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\53
# ---
# Папок нет
# ---
# Список файлов ['006585c0d7716d0e3903ffc777fd1d0c0ee4ca']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\53\006585c0d7716d0e3903ffc777fd1d0c0ee4ca
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\55
# ---
# Папок нет
# ---
# Список файлов ['56700b7fce8234abe74cdeba8b21c406ff4ec4']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\55\56700b7fce8234abe74cdeba8b21c406ff4ec4
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\57
# ---
# Папок нет
# ---
# Список файлов ['5584aec66cb583f0253ff548aa9b26f6716962', 'df50964824506aa3ebe1b792329e10217d24a0']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\57\5584aec66cb583f0253ff548aa9b26f6716962
# Файл  c:\Homework Skillfactory\.git\objects\57\df50964824506aa3ebe1b792329e10217d24a0
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\59
# ---
# Папок нет
# ---
# Список файлов ['51efadd3a0e0fbc504030ddd266015331738a5', '57c672c3df0e89467bc6da55402545451db715']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\59\51efadd3a0e0fbc504030ddd266015331738a5
# Файл  c:\Homework Skillfactory\.git\objects\59\57c672c3df0e89467bc6da55402545451db715
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\5a
# ---
# Папок нет
# ---
# Список файлов ['b73a0b61e5edd7f9921900d68070783ba8544d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\5a\b73a0b61e5edd7f9921900d68070783ba8544d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\5b
# ---
# Папок нет
# ---
# Список файлов ['c81133bf7375b64440be218d2e29502bf8498a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\5b\c81133bf7375b64440be218d2e29502bf8498a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\5c
# ---
# Папок нет
# ---
# Список файлов ['278beb6c35eab593aba423ff3e87cf6830d3e5', 'cb355d9a4a89316e0cba8e6272891ceaf6eb3f']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\5c\278beb6c35eab593aba423ff3e87cf6830d3e5
# Файл  c:\Homework Skillfactory\.git\objects\5c\cb355d9a4a89316e0cba8e6272891ceaf6eb3f
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\60
# ---
# Папок нет
# ---
# Список файлов ['5c5a018f71148a255e0f63b461daab859a5f0d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\60\5c5a018f71148a255e0f63b461daab859a5f0d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\64
# ---
# Папок нет
# ---
# Список файлов ['8c8a46148b9e9180b4818bfad6f98612ec919a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\64\8c8a46148b9e9180b4818bfad6f98612ec919a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\66
# ---
# Папок нет
# ---
# Список файлов ['d987b2e5a0269e4ee1e00b332a950c4a60ea96', 'eea94952a648b69bcaf3e575f333c8fab65f69']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\66\d987b2e5a0269e4ee1e00b332a950c4a60ea96
# Файл  c:\Homework Skillfactory\.git\objects\66\eea94952a648b69bcaf3e575f333c8fab65f69
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\67
# ---
# Папок нет
# ---
# Список файлов ['dc91f6e0f1ef13f97ed4396013b5253fc524e1']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\67\dc91f6e0f1ef13f97ed4396013b5253fc524e1
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\6b
# ---
# Папок нет
# ---
# Список файлов ['1a58b6646070f57f1a107048553d03c68b6d64', '4c28ba03b4fbf67a7633ff05d9442d8e51bcdf']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\6b\1a58b6646070f57f1a107048553d03c68b6d64
# Файл  c:\Homework Skillfactory\.git\objects\6b\4c28ba03b4fbf67a7633ff05d9442d8e51bcdf
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\6f
# ---
# Папок нет
# ---
# Список файлов ['383928f413c967aba4a30d8867b35ca3c7e437']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\6f\383928f413c967aba4a30d8867b35ca3c7e437
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\70
# ---
# Папок нет
# ---
# Список файлов ['2098479d46d6a2f6285ed3a06cda7e67f58ab3', '748e00a3a60b049181ad5d0c13a9c64ee6bd7b', '8c1efa08051eef48db56bb24093ee6aa897161', 'efa1b7e6a79a0fde11480f6ac8c52a4823f7b3']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\70\2098479d46d6a2f6285ed3a06cda7e67f58ab3
# Файл  c:\Homework Skillfactory\.git\objects\70\748e00a3a60b049181ad5d0c13a9c64ee6bd7b
# Файл  c:\Homework Skillfactory\.git\objects\70\8c1efa08051eef48db56bb24093ee6aa897161
# Файл  c:\Homework Skillfactory\.git\objects\70\efa1b7e6a79a0fde11480f6ac8c52a4823f7b3
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\71
# ---
# Папок нет
# ---
# Список файлов ['5264ce62b5462abce11839e3e012fa6c378fe2']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\71\5264ce62b5462abce11839e3e012fa6c378fe2
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\75
# ---
# Папок нет
# ---
# Список файлов ['57875916883818e108b26a14420bfd0168a1b7']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\75\57875916883818e108b26a14420bfd0168a1b7
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\77
# ---
# Папок нет
# ---
# Список файлов ['63924a74546c01426eabbb37866168ba837935']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\77\63924a74546c01426eabbb37866168ba837935
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\78
# ---
# Папок нет
# ---
# Список файлов ['b133b0484758accd7bb5c90eab26af92305f59']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\78\b133b0484758accd7bb5c90eab26af92305f59
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\7a
# ---
# Папок нет
# ---
# Список файлов ['857b1e2b0f0d3d11994c563220d87d7180fdde']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\7a\857b1e2b0f0d3d11994c563220d87d7180fdde
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\7d
# ---
# Папок нет
# ---
# Список файлов ['02792967b2dd30f559d7d23e313cb2c761caa4']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\7d\02792967b2dd30f559d7d23e313cb2c761caa4
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\83
# ---
# Папок нет
# ---
# Список файлов ['0bd00cb4503649a542afeef835d17c5b664494']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\83\0bd00cb4503649a542afeef835d17c5b664494
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\84
# ---
# Папок нет
# ---
# Список файлов ['282482d425868767ad9a8b9403b47d4b5a224b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\84\282482d425868767ad9a8b9403b47d4b5a224b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\85
# ---
# Папок нет
# ---
# Список файлов ['23e44e570b04b6e0023844c350120cff9a9d49', '2f7e409d1fd1002f3d61d098084b995c3da37c']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\85\23e44e570b04b6e0023844c350120cff9a9d49
# Файл  c:\Homework Skillfactory\.git\objects\85\2f7e409d1fd1002f3d61d098084b995c3da37c
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\86
# ---
# Папок нет
# ---
# Список файлов ['1a9f554263efb088d8636c4f17a30696e495ad']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\86\1a9f554263efb088d8636c4f17a30696e495ad
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\87
# ---
# Папок нет
# ---
# Список файлов ['f85bb6afc1dcf081bbce8fea5ca0e8cdb9a4f8']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\87\f85bb6afc1dcf081bbce8fea5ca0e8cdb9a4f8
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\88
# ---
# Папок нет
# ---
# Список файлов ['05c316f6b4fde609272217ac79142f77feb87c', '2666acc6374698bb6d4d61c09d207af59f4111']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\88\05c316f6b4fde609272217ac79142f77feb87c
# Файл  c:\Homework Skillfactory\.git\objects\88\2666acc6374698bb6d4d61c09d207af59f4111
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\8a
# ---
# Папок нет
# ---
# Список файлов ['4c206b4981fe4c70a0f994ccade69b6c2e7542', 'e9786599a3a8a764764463c29326beac609c26']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\8a\4c206b4981fe4c70a0f994ccade69b6c2e7542
# Файл  c:\Homework Skillfactory\.git\objects\8a\e9786599a3a8a764764463c29326beac609c26
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\8b
# ---
# Папок нет
# ---
# Список файлов ['137891791fe96927ad78e64b0aad7bded08bdc']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\8b\137891791fe96927ad78e64b0aad7bded08bdc
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\90
# ---
# Папок нет
# ---
# Список файлов ['ac6404225fcac38d9e795c621dfdff180262f4']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\90\ac6404225fcac38d9e795c621dfdff180262f4
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\93
# ---
# Папок нет
# ---
# Список файлов ['47bd326b9ab51cf7c8d7217d3411c2a8613f12']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\93\47bd326b9ab51cf7c8d7217d3411c2a8613f12
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\95
# ---
# Папок нет
# ---
# Список файлов ['49d07db8a46cd8866ef3bf7aa623fc2860a8af']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\95\49d07db8a46cd8866ef3bf7aa623fc2860a8af
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\97
# ---
# Папок нет
# ---
# Список файлов ['6727d3cc3270e3be3bccc3dd0be6f069e6c566']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\97\6727d3cc3270e3be3bccc3dd0be6f069e6c566
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\98
# ---
# Папок нет
# ---
# Список файлов ['21b3689e94eb4b32c03f5d902ced08c91b4850']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\98\21b3689e94eb4b32c03f5d902ced08c91b4850
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\9c
# ---
# Папок нет
# ---
# Список файлов ['63532a40783965f45322e6a62e0fd93f07e1a6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\9c\63532a40783965f45322e6a62e0fd93f07e1a6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\9d
# ---
# Папок нет
# ---
# Список файлов ['43b57f2d118293f3159903f2d4255a5562ea2d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\9d\43b57f2d118293f3159903f2d4255a5562ea2d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\a1
# ---
# Папок нет
# ---
# Список файлов ['124a0e897ed4f066a4227d991fef300550df5d', '90f06f958a9cba89cb87dc9a75f98cf3352da7', 'c1463f84f6e1beeca5c98f6a93cc72bd32db65']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\a1\124a0e897ed4f066a4227d991fef300550df5d
# Файл  c:\Homework Skillfactory\.git\objects\a1\90f06f958a9cba89cb87dc9a75f98cf3352da7
# Файл  c:\Homework Skillfactory\.git\objects\a1\c1463f84f6e1beeca5c98f6a93cc72bd32db65
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\a4
# ---
# Папок нет
# ---
# Список файлов ['16e7528b21a4f2f075a1b879715be4a78eb9a1', 'c05bd281ee7a9675160c4a11c6eb84694f77b8']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\a4\16e7528b21a4f2f075a1b879715be4a78eb9a1
# Файл  c:\Homework Skillfactory\.git\objects\a4\c05bd281ee7a9675160c4a11c6eb84694f77b8
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\a5
# ---
# Папок нет
# ---
# Список файлов ['11fbec3a0222a84b37b4ad0bd597538bf62b8e', 'cf918d8a1c4b8570d856e9393af0362ea35c4d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\a5\11fbec3a0222a84b37b4ad0bd597538bf62b8e
# Файл  c:\Homework Skillfactory\.git\objects\a5\cf918d8a1c4b8570d856e9393af0362ea35c4d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\a6
# ---
# Папок нет
# ---
# Список файлов ['26141f82ac1966f5f57aa8a12b34d56ba7771f', '753067786fc93b4f5e9affa98a700461e0ef79']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\a6\26141f82ac1966f5f57aa8a12b34d56ba7771f
# Файл  c:\Homework Skillfactory\.git\objects\a6\753067786fc93b4f5e9affa98a700461e0ef79
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\a9
# ---
# Папок нет
# ---
# Список файлов ['5189db28a01b6ad934d5f7dbc8b95530a7c117', 'bf1f61b52daa3f79f4c2469187119854e3b8b6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\a9\5189db28a01b6ad934d5f7dbc8b95530a7c117
# Файл  c:\Homework Skillfactory\.git\objects\a9\bf1f61b52daa3f79f4c2469187119854e3b8b6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ab
# ---
# Папок нет
# ---
# Список файлов ['709e65c76a5d2756d043a609a37400821a2784']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ab\709e65c76a5d2756d043a609a37400821a2784
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ac
# ---
# Папок нет
# ---
# Список файлов ['15d05e25dcda60eb1a7575fea8f253c35ecaba']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ac\15d05e25dcda60eb1a7575fea8f253c35ecaba
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b0
# ---
# Папок нет
# ---
# Список файлов ['35f487fa914a1c36c679154aa63e3312da5cac']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b0\35f487fa914a1c36c679154aa63e3312da5cac
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b1
# ---
# Папок нет
# ---
# Список файлов ['258d6a0907def6ad8e6e555db3c1c65e9be14c', '92a2ef918c49cf044f0a89b3442d6bdb0f619f', 'ffb49a5ee98deab56251b2a40a9e76b1c48b65']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b1\258d6a0907def6ad8e6e555db3c1c65e9be14c
# Файл  c:\Homework Skillfactory\.git\objects\b1\92a2ef918c49cf044f0a89b3442d6bdb0f619f
# Файл  c:\Homework Skillfactory\.git\objects\b1\ffb49a5ee98deab56251b2a40a9e76b1c48b65
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b2
# ---
# Папок нет
# ---
# Список файлов ['b851e5463c797abf34a59490a5afac0f39e7f7']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b2\b851e5463c797abf34a59490a5afac0f39e7f7
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b3
# ---
# Папок нет
# ---
# Список файлов ['61f0cf6b9b60bc7e9989910d95c936404a944c']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b3\61f0cf6b9b60bc7e9989910d95c936404a944c
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b7
# ---
# Папок нет
# ---
# Список файлов ['1719fdc1a547aafa5189dc122c314760030f9f', 'f7085926972af656acb8215543ffe234c6feeb']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b7\1719fdc1a547aafa5189dc122c314760030f9f
# Файл  c:\Homework Skillfactory\.git\objects\b7\f7085926972af656acb8215543ffe234c6feeb
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\b9
# ---
# Папок нет
# ---
# Список файлов ['0af466bb4690850d3212729ee6e8b56b111148', '3a1c5676a9dd46aeabb351a9acfadd9326d47f', 'd6d29ed7af2def36f3705e24837a27d1b97a47']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\b9\0af466bb4690850d3212729ee6e8b56b111148
# Файл  c:\Homework Skillfactory\.git\objects\b9\3a1c5676a9dd46aeabb351a9acfadd9326d47f
# Файл  c:\Homework Skillfactory\.git\objects\b9\d6d29ed7af2def36f3705e24837a27d1b97a47
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ba
# ---
# Папок нет
# ---
# Список файлов ['d3e4ed08eeffb99261581eef16b25561b8d53d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ba\d3e4ed08eeffb99261581eef16b25561b8d53d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\bb
# ---
# Папок нет
# ---
# Список файлов ['712248012d186eeae393d4827f9a13bd5affcc', '728ea797a83fee998150b3dbfcd66b9dd8221c', '8dc621550fa2ce73c13f3a1e2de3ed3ed75477']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\bb\712248012d186eeae393d4827f9a13bd5affcc
# Файл  c:\Homework Skillfactory\.git\objects\bb\728ea797a83fee998150b3dbfcd66b9dd8221c
# Файл  c:\Homework Skillfactory\.git\objects\bb\8dc621550fa2ce73c13f3a1e2de3ed3ed75477
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\bd
# ---
# Папок нет
# ---
# Список файлов ['98865d81ef3cd0183f344f3148331a48a68d31']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\bd\98865d81ef3cd0183f344f3148331a48a68d31
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\c4
# ---
# Папок нет
# ---
# Список файлов ['a8335cae5d11a948f739f062c2da0f2af43ae3']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\c4\a8335cae5d11a948f739f062c2da0f2af43ae3
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\c5
# ---
# Папок нет
# ---
# Список файлов ['e75ace4c99e2ff89ad1f2b9d8d50d6e503a76a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\c5\e75ace4c99e2ff89ad1f2b9d8d50d6e503a76a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\c7
# ---
# Папок нет
# ---
# Список файлов ['d3f4bc72f9d5fa6ccfc51a0423a50b615539ce', 'd822c7b86545c122bbbef1b37b943365c78c29']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\c7\d3f4bc72f9d5fa6ccfc51a0423a50b615539ce
# Файл  c:\Homework Skillfactory\.git\objects\c7\d822c7b86545c122bbbef1b37b943365c78c29
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\c8
# ---
# Папок нет
# ---
# Список файлов ['dda03e528c296af1d7c5f47fb498e3b7fdb821', 'e7f8cad686e4a172e789b727a049ed32dd44ad']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\c8\dda03e528c296af1d7c5f47fb498e3b7fdb821
# Файл  c:\Homework Skillfactory\.git\objects\c8\e7f8cad686e4a172e789b727a049ed32dd44ad
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\cd
# ---
# Папок нет
# ---
# Список файлов ['001e63648fa70a2ae7fb49d7e1198ab70dd0f7', 'a39a44b2b22f03d53f895ff0c2e580de7fefc6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\cd\001e63648fa70a2ae7fb49d7e1198ab70dd0f7
# Файл  c:\Homework Skillfactory\.git\objects\cd\a39a44b2b22f03d53f895ff0c2e580de7fefc6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ce
# ---
# Папок нет
# ---
# Список файлов ['ebdf49edc520c79a66e91d9e3841e434dc359d']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ce\ebdf49edc520c79a66e91d9e3841e434dc359d
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\d2
# ---
# Папок нет
# ---
# Список файлов ['0ab1fd36abca7c3ea78520fd04e1d9a06b088c', '6342f222e2ce9af8b89f4cbefc06d1fc880e3e', 'd00db6da074dee97cf1c930901c73683f82c1e', 'fbbc28c3ffcdcd5c60b07264d8ff9ff1abef48']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\d2\0ab1fd36abca7c3ea78520fd04e1d9a06b088c
# Файл  c:\Homework Skillfactory\.git\objects\d2\6342f222e2ce9af8b89f4cbefc06d1fc880e3e
# Файл  c:\Homework Skillfactory\.git\objects\d2\d00db6da074dee97cf1c930901c73683f82c1e
# Файл  c:\Homework Skillfactory\.git\objects\d2\fbbc28c3ffcdcd5c60b07264d8ff9ff1abef48
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\d4
# ---
# Папок нет
# ---
# Список файлов ['e2c13981373f0d4662310070da9d1784f754a0']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\d4\e2c13981373f0d4662310070da9d1784f754a0
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\d6
# ---
# Папок нет
# ---
# Список файлов ['687258292d4898d9e2686af738f7be14c28936', 'b0207bc00f07b701192004fd672a93f4e5526b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\d6\687258292d4898d9e2686af738f7be14c28936
# Файл  c:\Homework Skillfactory\.git\objects\d6\b0207bc00f07b701192004fd672a93f4e5526b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\d7
# ---
# Папок нет
# ---
# Список файлов ['fd3b16a6648391e19059094e19a123d7a54e6a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\d7\fd3b16a6648391e19059094e19a123d7a54e6a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\db
# ---
# Папок нет
# ---
# Список файлов ['571db1c48f0af25c98b75a45959fa0d1e5984a']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\db\571db1c48f0af25c98b75a45959fa0d1e5984a
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\dc
# ---
# Папок нет
# ---
# Список файлов ['b7daa15742fc79dc4c3d59bac5a3d6acfb7190']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\dc\b7daa15742fc79dc4c3d59bac5a3d6acfb7190
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\de
# ---
# Папок нет
# ---
# Список файлов ['4a4c32e0c54242ac12d006f26a1b5177581b25']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\de\4a4c32e0c54242ac12d006f26a1b5177581b25
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e0
# ---
# Папок нет
# ---
# Список файлов ['a40228a3b1c29ea2b39a48bee8277233cbc383']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e0\a40228a3b1c29ea2b39a48bee8277233cbc383
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e2
# ---
# Папок нет
# ---
# Список файлов ['041c5f323b1bf654ff7b0834fd07b7a1994b00', 'd3a582b7c463b5d5ecfb60194a4df20647a4cf', 'e55ad57387c29df0874ec1360e711ae5969233']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e2\041c5f323b1bf654ff7b0834fd07b7a1994b00
# Файл  c:\Homework Skillfactory\.git\objects\e2\d3a582b7c463b5d5ecfb60194a4df20647a4cf
# Файл  c:\Homework Skillfactory\.git\objects\e2\e55ad57387c29df0874ec1360e711ae5969233
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e3
# ---
# Папок нет
# ---
# Список файлов ['d41dcbc1504afc1b9c82e499a29fd3b1cf0af6']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e3\d41dcbc1504afc1b9c82e499a29fd3b1cf0af6
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e4
# ---
# Папок нет
# ---
# Список файлов ['306dffc73b96f5d39ac0979ff72dccfb8b2b2b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e4\306dffc73b96f5d39ac0979ff72dccfb8b2b2b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e6
# ---
# Папок нет
# ---
# Список файлов ['9de29bb2d1d6434b8b29ae775ad8c2e48c5391']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e6\9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\e7
# ---
# Папок нет
# ---
# Список файлов ['f4529fa67f4d620e380b9577ed4069c8ee9954']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\e7\f4529fa67f4d620e380b9577ed4069c8ee9954
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\eb
# ---
# Папок нет
# ---
# Список файлов ['a1d5f5d5885f1fd0f5b1c7adb62a7add55fa85']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\eb\a1d5f5d5885f1fd0f5b1c7adb62a7add55fa85
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ec
# ---
# Папок нет
# ---
# Список файлов ['039807e54c95e4405f6594d483c8596ab1ea8b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ec\039807e54c95e4405f6594d483c8596ab1ea8b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ee
# ---
# Папок нет
# ---
# Список файлов ['dfd9c072d35f198a3caeba57ff77c39c1b1d6b']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ee\dfd9c072d35f198a3caeba57ff77c39c1b1d6b
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\f0
# ---
# Папок нет
# ---
# Список файлов ['6c1fcca79bf2a83626ecbb762890f94a7628c8', 'fc30df1d45226d63408f138a04a44109afbd46']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\f0\6c1fcca79bf2a83626ecbb762890f94a7628c8
# Файл  c:\Homework Skillfactory\.git\objects\f0\fc30df1d45226d63408f138a04a44109afbd46
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\f1
# ---
# Папок нет
# ---
# Список файлов ['5d522b25637c1afe2afa71e2dc96129b2d7676']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\f1\5d522b25637c1afe2afa71e2dc96129b2d7676
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\f5
# ---
# Папок нет
# ---
# Список файлов ['d49746eff194c7613c0d9025798c30d0aa77b5']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\f5\d49746eff194c7613c0d9025798c30d0aa77b5
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\f7
# ---
# Папок нет
# ---
# Список файлов ['2e65de4e04fbaedf87ca8597253464ab96cd32']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\f7\2e65de4e04fbaedf87ca8597253464ab96cd32
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\f8
# ---
# Папок нет
# ---
# Список файлов ['0ce6aac7903c311f96f1630facb551c6c091a7', '8e17094e93d00b98f1c427e38a1dde75e194d5', 'c7fa73d2d2368a6453c18aed160526f2e4da07']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\f8\0ce6aac7903c311f96f1630facb551c6c091a7
# Файл  c:\Homework Skillfactory\.git\objects\f8\8e17094e93d00b98f1c427e38a1dde75e194d5
# Файл  c:\Homework Skillfactory\.git\objects\f8\c7fa73d2d2368a6453c18aed160526f2e4da07
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\fa
# ---
# Папок нет
# ---
# Список файлов ['423ef6a1e51e745bfe4a706076e5c1fdaa62a5', '65d7deacd1e8ba494eaaf5beb8b233ed2fac88', 'd5afe87c6f85626016b09e2aec354b004c461c']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\fa\423ef6a1e51e745bfe4a706076e5c1fdaa62a5
# Файл  c:\Homework Skillfactory\.git\objects\fa\65d7deacd1e8ba494eaaf5beb8b233ed2fac88
# Файл  c:\Homework Skillfactory\.git\objects\fa\d5afe87c6f85626016b09e2aec354b004c461c
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\fd
# ---
# Папок нет
# ---
# Список файлов ['8456f1f263ad1495cf4bd664cb33f2d93de600']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\fd\8456f1f263ad1495cf4bd664cb33f2d93de600
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\ff
# ---
# Папок нет
# ---
# Список файлов ['45c1911944e82e403f211d1efdffa802c98c48']
# ---
# Файл  c:\Homework Skillfactory\.git\objects\ff\45c1911944e82e403f211d1efdffa802c98c48
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\.git\objects\pack
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\.git\refs
# ---
# ...
# ---
# Папок нет
# ---
# Список файлов ['churn.csv', 'citibike-tripdata.csv', 'countries.csv', 'countries.txt', 'countries.xlsx', 'country_vaccinations.csv', 'country_vaccinations_updated.csv', 'covid_19_data.csv', 'covid_data.csv', 'Data_TSUM.xlsx', 'dates.csv', 'diabetes_data.csv', 'melb_data.csv', 'melb_data_fe.csv', 'melb_data_ps.csv', 'movies.csv', 'orders.csv', 'products.csv', 'ratings1.csv', 'ratings2.csv', 'ratings_movies.csv', 'sber_data.csv', 'students_performance.csv', 'ufo.txt', 'Таблица для инфоцентра 2019-2020 .xlsx', 'Таблица для инфоцентра 2021.xlsx', 'Таблица для инфоцентра 2022.xlsx']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\churn.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\citibike-tripdata.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.txt
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\country_vaccinations.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\country_vaccinations_updated.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\covid_19_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\covid_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Data_TSUM.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\dates.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\diabetes_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data_fe.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data_ps.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\movies.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\orders.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\products.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings1.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings2.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings_movies.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\sber_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\students_performance.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ufo.txt
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2019-2020 .xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2021.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2022.xlsx
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\helpers
# ---
# Папок нет
# ---
# Список файлов ['client_class.py', 'DataFrame_class.py', '__init__.py']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\client_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\DataFrame_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\__init__.py
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__
# ---
# Папок нет
# ---
# Список файлов ['Client.cpython-310.pyc', 'client_class.cpython-310.pyc', 'DataFrame_class.cpython-310.pyc']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\Client.cpython-310.pyc
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\client_class.cpython-310.pyc
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\DataFrame_class.cpython-310.pyc
# ===
# Текущая директория c:\Homework Skillfactory\Block3 SF
# ---
# Список папок ['data_test']
# ---
# Список файлов ['Data loading.ipynb']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\Block3 SF\Data loading.ipynb
# Папка  c:\Homework Skillfactory\Block3 SF\data_test
# ===
# Текущая директория c:\Homework Skillfactory\Block3 SF\data_test
# ---
# Папок нет
# ---
# Список файлов ['countries.csv', 'countries.txt', 'countries.xlsx', 'melb_data.csv', 'students_performance.csv', 'транспод.xlsx']
# ---
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\countries.csv
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\countries.txt
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\countries.xlsx
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\melb_data.csv
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\students_performance.csv
# Файл  c:\Homework Skillfactory\Block3 SF\data_test\транспод.xlsx
# ===
# Текущая директория c:\Homework Skillfactory\data
# ---
# Папок нет
# ---
# Список файлов ['churn.zip', 'citibike-tripdata.csv', 'countries.csv', 'countries.xlsx', 'country_vaccinations.csv', 'country_vaccinations.csv.zip', 'country_vaccinations.zip', 'covid_19_data.csv.zip', 'covid_data.csv', 'covid_data.zip', 'dates.csv', 'diabetes_data.zip', 'melb_data.csv', 'movies.csv', 'movies_data.zip', 'Odesmiskelektrotrans_2022-09-07.csv', 'Odesmiskelektrotrans_2022-09-08.csv', 'orders.csv', 'orders_and_products.zip', 'products.csv', 'ratings1.csv', 'ratings2.csv', 'ratings_movies.csv', 'ratings_movies.zip', 'sber_data.zip', 'students_performance.csv', 'ufo.txt', 'yandex_realty_data.csv', 'Сводные таблицы & Дэшборды.xlsx', 'Таблица для инфоцентра 2019-2020 .xlsx', 'Таблица для инфоцентра 2021.xlsx', 'Таблица для инфоцентра 2022.xlsx', 'ТРАМВАЙ.xlsx']
# ---
# Файл  c:\Homework Skillfactory\data\churn.zip
# Файл  c:\Homework Skillfactory\data\citibike-tripdata.csv
# Файл  c:\Homework Skillfactory\data\countries.csv
# Файл  c:\Homework Skillfactory\data\countries.xlsx
# Файл  c:\Homework Skillfactory\data\country_vaccinations.csv
# Файл  c:\Homework Skillfactory\data\country_vaccinations.csv.zip
# Файл  c:\Homework Skillfactory\data\country_vaccinations.zip
# Файл  c:\Homework Skillfactory\data\covid_19_data.csv.zip
# Файл  c:\Homework Skillfactory\data\covid_data.csv
# Файл  c:\Homework Skillfactory\data\covid_data.zip
# Файл  c:\Homework Skillfactory\data\dates.csv
# Файл  c:\Homework Skillfactory\data\diabetes_data.zip
# Файл  c:\Homework Skillfactory\data\melb_data.csv
# Файл  c:\Homework Skillfactory\data\movies.csv
# Файл  c:\Homework Skillfactory\data\movies_data.zip
# Файл  c:\Homework Skillfactory\data\Odesmiskelektrotrans_2022-09-07.csv
# Файл  c:\Homework Skillfactory\data\Odesmiskelektrotrans_2022-09-08.csv
# Файл  c:\Homework Skillfactory\data\orders.csv
# Файл  c:\Homework Skillfactory\data\orders_and_products.zip
# Файл  c:\Homework Skillfactory\data\products.csv
# Файл  c:\Homework Skillfactory\data\ratings1.csv
# Файл  c:\Homework Skillfactory\data\ratings2.csv
# Файл  c:\Homework Skillfactory\data\ratings_movies.csv
# Файл  c:\Homework Skillfactory\data\ratings_movies.zip
# Файл  c:\Homework Skillfactory\data\sber_data.zip
# Файл  c:\Homework Skillfactory\data\students_performance.csv
# Файл  c:\Homework Skillfactory\data\ufo.txt
# Файл  c:\Homework Skillfactory\data\yandex_realty_data.csv
# Файл  c:\Homework Skillfactory\data\Сводные таблицы & Дэшборды.xlsx
# Файл  c:\Homework Skillfactory\data\Таблица для инфоцентра 2019-2020 .xlsx
# Файл  c:\Homework Skillfactory\data\Таблица для инфоцентра 2021.xlsx
# Файл  c:\Homework Skillfactory\data\Таблица для инфоцентра 2022.xlsx
# Файл  c:\Homework Skillfactory\data\ТРАМВАЙ.xlsx
# ===
# Текущая директория c:\Homework Skillfactory\graphics.py-5.0.1.post1
# ---
# Список папок ['graphics', 'graphics.py.egg-info']
# ---
# Список файлов ['PKG-INFO', 'setup.cfg', 'setup.py']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\PKG-INFO
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\setup.cfg
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\setup.py
# Папка  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics
# Папка  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info
# ===
# Текущая директория c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics
# ---
# Папок нет
# ---
# Список файлов ['__init__.py']
# ---
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics\__init__.py
# ===
# Текущая директория c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info
# ---
# Папок нет
# ---
# Список файлов ['dependency_links.txt', 'not-zip-safe', 'PKG-INFO', 'SOURCES.txt', 'top_level.txt']
# ---
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info\dependency_links.txt
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info\not-zip-safe
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info\PKG-INFO
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info\SOURCES.txt
# Файл  c:\Homework Skillfactory\graphics.py-5.0.1.post1\graphics.py.egg-info\top_level.txt
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__
# ---
# Список папок ['preview']
# ---
# Список файлов ['game_v2.cpython-310.pyc']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\__pycache__\game_v2.cpython-310.pyc
# Папка  c:\Homework Skillfactory\__pycache__\preview
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview
# ---
# Список папок ['ImageIO', 'Matplotlib', 'OpenCV', 'PIL', 'Plotly', 'Pytorch', 'Tensorflow']
# ---
# Файлов нет
# ---
# Папка  c:\Homework Skillfactory\__pycache__\preview\ImageIO
# Папка  c:\Homework Skillfactory\__pycache__\preview\Matplotlib
# Папка  c:\Homework Skillfactory\__pycache__\preview\OpenCV
# Папка  c:\Homework Skillfactory\__pycache__\preview\PIL
# Папка  c:\Homework Skillfactory\__pycache__\preview\Plotly
# Папка  c:\Homework Skillfactory\__pycache__\preview\Pytorch
# Папка  c:\Homework Skillfactory\__pycache__\preview\Tensorflow
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\ImageIO
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\Matplotlib
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\OpenCV
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\PIL
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\Plotly
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\Pytorch
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\__pycache__\preview\Tensorflow
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas
# ---
# Список папок ['archive', 'data_test', 'helpers', '__pycache__']
# ---
# Список файлов ['client_class.py', 'DataFrame_class.py', 'Pandas cleaning data.ipynb', 'Pandas Data Joining.ipynb', 'Pandas Data manipulation.ipynb', 'Pandas Data manipulation2.ipynb', 'Pandas Data Viualisation.ipynb', 'Pandas DataFrame Practise.ipynb', 'Pandas DataFrame.ipynb', 'Pandas OOP code debugging.ipynb', 'Pandas series.ipynb', 'Pandas Visualisation practise bank.ipynb', 'Types_of_visualization.ipynb', 'Visualization_Pandas.ipynb', 'Viualisation.ipynb', '__init__.py']
# ---
# Все пути:
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\client_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\DataFrame_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas cleaning data.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas Data Joining.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas Data manipulation.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas Data manipulation2.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas Data Viualisation.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas DataFrame Practise.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas DataFrame.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas OOP code debugging.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas series.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Pandas Visualisation practise bank.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Types_of_visualization.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Visualization_Pandas.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\Viualisation.ipynb
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__init__.py
# Папка  c:\Homework Skillfactory\Block2 SF\Pandas\archive
# Папка  c:\Homework Skillfactory\Block2 SF\Pandas\data_test
# Папка  c:\Homework Skillfactory\Block2 SF\Pandas\helpers
# Папка  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\archive
# ---
# Папок нет
# ---
# Список файлов ['23-01-17.pkl']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\archive\23-01-17.pkl
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\data_test
# ---
# Папок нет
# ---
# Список файлов ['churn.csv', 'citibike-tripdata.csv', 'countries.csv', 'countries.txt', 'countries.xlsx', 'country_vaccinations.csv', 'country_vaccinations_updated.csv', 'covid_19_data.csv', 'covid_data.csv', 'Data_TSUM.xlsx', 'dates.csv', 'diabetes_data.csv', 'melb_data.csv', 'melb_data_fe.csv', 'melb_data_ps.csv', 'movies.csv', 'orders.csv', 'products.csv', 'ratings1.csv', 'ratings2.csv', 'ratings_movies.csv', 'sber_data.csv', 'students_performance.csv', 'ufo.txt', 'Таблица для инфоцентра 2019-2020 .xlsx', 'Таблица для инфоцентра 2021.xlsx', 'Таблица для инфоцентра 2022.xlsx']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\churn.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\citibike-tripdata.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.txt
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\countries.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\country_vaccinations.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\country_vaccinations_updated.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\covid_19_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\covid_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Data_TSUM.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\dates.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\diabetes_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data_fe.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\melb_data_ps.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\movies.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\orders.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\products.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings1.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings2.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ratings_movies.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\sber_data.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\students_performance.csv
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\ufo.txt
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2019-2020 .xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2021.xlsx
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\data_test\Таблица для инфоцентра 2022.xlsx
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\helpers
# ---
# Папок нет
# ---
# Список файлов ['client_class.py', 'DataFrame_class.py', '__init__.py']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\client_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\DataFrame_class.py
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\helpers\__init__.py
# ===
# Текущая директория c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__
# ---
# Папок нет
# ---
# Список файлов ['Client.cpython-310.pyc', 'client_class.cpython-310.pyc', 'DataFrame_class.cpython-310.pyc']
# ---
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\Client.cpython-310.pyc
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\client_class.cpython-310.pyc
# Файл  c:\Homework Skillfactory\Block2 SF\Pandas\__pycache__\DataFrame_class.cpython-310.pyc
# ===

# %%
"""Python «из коробки» располагает достаточно широким набором инструментов для работы с файлами. Для того чтобы начать
работать с файлом, надо его открыть с помощью команды специальной функции open: 
f=open('path\to\file','filemode',encoding='utf8')
Результатом этой операции будет файл, в котором указатель текущей позиции поставлен на начало или конец файла.
Давайте по порядку разберём все аргументы:

path/to/file — путь к файлу может быть относительным или абсолютным. Можно указывать в Unix-стиле (path/to/file)
или в Windows-стиле (path\to\file).

filemode — режим, в котором файл нужно открывать.
Записывается в виде строки, может принимать следующие значения:
r — открыть на чтение (по умолчанию);
w — перезаписать и открыть на запись (если файла нет, то он создастся);
x — создать и открыть на запись (если уже есть — исключение);
a — открыть на дозапись (указатель будет поставлен в конец);
t — открыть в текстовом виде (по умолчанию);
b — открыть в бинарном виде.

encoding — указание, в какой кодировке файл записан (utf8, cp1251 и т. д.) По умолчанию стоит utf-8.
При этом можно записывать кодировку как через дефис, так и без: utf-8 или utf8."""
#Откроем файл на запись и с помощью метода write запишем в него строку. В качестве результата метод write возвращает
#количество записанных символов.
f=open('text.txt','w',encoding='utf8')
#Write string in file
f.write("This is a test string\n")
f.write("This is a new string\n")
"""После вызова команды write ваши данные не сразу попадут и сохранятся в файл. Связано это с особенностями
внутренней работы операционных систем. Если для вас критично своевременное попадание информации на жесткий диск
компьютера, то после записи вызывайте f.flush() или закрывайте файл. Закрыть файл можно с помощью метода close()."""
# обязательно нужно закрыть файл иначе он будет заблокирован ОС
f.close()
#Откроем файл для чтения, в который только что записали две строки:
f=open('text.txt','r',encoding='ascii')#ascii-english; utf8-all languages; koi8_u-ukrainian
"""f.read(n) — операция, читающая с текущего места n символов, если файл открыт в t режиме, или n байт, если файл
открыт в b режиме, и возвращающая прочитанную информацию."""
#После того, как файл открыт для чтения, мы можем читать из него данные.
print(f.read(10))
"""После прочтения указатель на содержимое остается на той позиции, где чтение закончилось. Если n не указать, будет
прочитано «от печки», то есть от текущего места указателя и до самого конца файла."""
# считали остаток файла
print(f.read()) # test string\nThis is a new string\n
#После работы обязательно закрываем файл:
f.close()

"""ЧТЕНИЕ И ЗАПИСЬ ПОСТРОЧНО
Зачастую с файлами удобнее работать построчно, поэтому для этого есть отдельные методы:
writelines — записывает список строк в файл;
readline — считывает из файла одну строку и возвращает её;
readlines — считывает из файла все строки в список и возвращает их.
Метод f.writelines(sequence) не будет сам за вас дописывать символ конца строки ('\n'), поэтому при необходимости
его нужно прописать вручную."""

f = open('test.txt', 'a', encoding='utf8') # открываем файл на дозапись(a)
sequence = ["other string\n", "123\n", "test test\n"]
f.writelines(sequence) # берет строки из sequence и записывает в файл (без переносов)
f.close()
#Попробуем теперь построчно считать файл с помощью readlines:
f = open('test.txt', 'r', encoding='utf8')
print(f.readlines()) # считывает все строки в список и возвращает список
f.close()#why create 2 files test.txt?
"""Метод f.readline() возвращает строку (символы от текущей позиции до символа переноса строки \n, который остаётся
в конце строки и опускается только в последней строке файла, если файл не заканчивается новой строкой):"""
f=open('test.txt','r',encoding='utf8')
print(f.readline()) # This is a test string
print(f.read(4)) # This
print(f.readline()) # is a new string
f.close()

"""ФАЙЛ КАК ИТЕРАТОР
Объект файл является итератором, поэтому его можно использовать в цикле for.
Не стоит считывать файл полностью — в большинстве задач с обработкой текста весь файл разом читать не требуется.
В таком случае с файлом работают построчно."""
f = open('test.txt')  # можно перечислять строки в файле
print('File as iterator theme')
for line in f:
    print(line, end='')
# This is a test string
# This is a new string
# other string
# 123
# test test
f.close()
"""МЕНЕДЖЕР КОНТЕКСТА WITH
После работы с файлом его необходимо закрыть с помощью метода close(). Файл освобождается для операционной системы
(если он был открыт для записи), и другие приложения могут получать к нему доступ. Если не закрыть файл явно, то
информация, записываемая в него, может быть утеряна, или файл может повредиться.
Для явного указания места работы с файлом, а также чтобы не забывать закрывать файл после обработки, существует
менеджер контекста with."""
# В блоке менеджера контекста открытый файл «жив» и с ним можно работать, при выходе из блока - файл закрывается.
with open("test.txt", 'rb') as f:
    a = f.read(10)#why use variable
    b = f.read(23)
print(a)
print(b)
f.read(3) # Error!Тело менеджера контекста определяется одним отступом вправо относительно отступов ключевого слова
#with. Менеджер контекста неявно вызывает закрытие файла после работы, что освобождает вас от забот о том, закрыли
#ли вы файл или нет.Закрытие файла происходит при любом стечении обстоятельств, даже если внутри with будет ошибка.
# Out:
# This is a
# test string
# This is a new string
#
# ['other string\n', '123\n', 'test test\n', 'other string\n', '123\n', 'test test\n', 'other string\n', '123\n', 'test test\n', 'other string\n', '123\n', 'test test\n', 'other string\n', '123\n', 'test test\n', 'other string\n', '123\n', 'test test\n']
# other string
#
# 123
#
# test test
#
# File as iterator theme
# other string
# 123
# test test
# other string
# 123
# test test
# other string
# 123
# test test
# other string
# 123
# test test
# other string
# 123
# test test
# other string
# 123
# test test
# b'other stri'
# b'ng\r\n123\r\ntest test\r\noth'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 95
#      93 print(a)
#      94 print(b)
# ---> 95 f.read(3)
#
# ValueError: read of closed file

# %%
#Создайте любой файл на операционной системе под название input.txt и построчно перепишите его в файл output.txt.
test_1=open("input.txt",'w',encoding='utf8')
test_2=open("output.txt",'w',encoding='utf8')
test_1.write("Testing these files,\nShould be fun!)\n")
test_1,test_2.close()
test_1=open('input.txt','r',encoding='utf8')
print(test_1.read())
test_2=open("output.txt",'a',encoding='utf8')
#test_1.close()
for line in test_1:
    test_2.writelines(line)
test_1,test_2.close()    
test_2=open('input.txt','r',encoding='utf8')
print(test_2.read())
test_2.close()

with open("input.txt", "r") as test_1:
    with open("output.txt", "w") as test_2:
        for line in test_1:
            test_2.write(line)
test_1.close()
test_2.close()
# Out:
# Testing these files,
# Should be fun!)
#
# Testing these files,
# Should be fun!)

# %%
#Дан файл numbers.txt, компоненты которого являются действительными числами (файл создайте самостоятельно и заполните
#любыми числам, в одной строке одно число). Найдите сумму наибольшего и наименьшего из значений и запишите результат
#в файл output.txt.
with open ('numbers.txt','w') as numbers_t:
    for i in range(10):
        numbers_t.write (i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 6
#       4 with open ('numbers.txt','w') as numbers_t:
#       5     for i in range(10):
# ----> 6         numbers_t.write (i)
#
# TypeError: write() argument must be str, not int

# %%
#В текстовый файл построчно записаны фамилии и имена учащихся класса и их оценки за контрольную. Подсчитайте
#количество учащихся, чья оценка меньше 3 баллов. Cодержание файла:

Иванов О. 4
Петров И. 3
Дмитриев Н. 2
Смирнова О. 4
Керченских В. 5
Котов Д. 2
Бирюкова Н. 1
Данилов П. 3
Аранских В. 5
Лемонов Ю. 2
Олегова К. 4

# %%
pip list
# Out:
# Package            Version
# ------------------ -----------
# asttokens          2.0.8
# attrs              22.1.0
# backcall           0.2.0
# certifi            2022.12.7
# charset-normalizer 3.0.1
# colorama           0.4.5
# contourpy          1.0.6
# cycler             0.11.0
# debugpy            1.6.3
# decorator          5.1.1
# entrypoints        0.4
# et-xmlfile         1.1.0
# executing          1.0.0
# fastjsonschema     2.16.2
# fonttools          4.38.0
# graphics.py        5.0.1.post1
# idna               3.4
# ipykernel          6.15.3
# ipython            8.5.0
# jedi               0.18.1
# jsonschema         4.17.3
# jupyter_client     7.3.5
# jupyter-core       4.11.1
# kiwisolver         1.4.4
# matplotlib         3.6.2
# matplotlib-inline  0.1.6
# nbformat           5.7.0
# nest-asyncio       1.5.5
# numpy              1.23.3
# openpyxl           3.0.10
# packaging          21.3
# pandas             1.5.0
# parso              0.8.3
# pickleshare        0.7.5
# Pillow             9.3.0
# pip                22.3.1
# plotly             5.11.0
# prompt-toolkit     3.0.31
# psutil             5.9.2
# pure-eval          0.2.2
# pygame             2.1.2
# Pygments           2.13.0
# pyparsing          3.0.9
# pyrsistent         0.19.2
# pyTelegramBotAPI   4.9.0
# python-dateutil    2.8.2
# pytz               2022.4
# pywin32            304
# pyzmq              24.0.0
# requests           2.28.2
# seaborn            0.12.1
# setuptools         63.2.0
# six                1.16.0
# stack-data         0.5.0
# tenacity           8.1.0
# tornado            6.2
# traitlets          5.4.0
# urllib3            1.26.14
# wcwidth            0.2.5
# Note: you may need to restart the kernel to use updated packages.
